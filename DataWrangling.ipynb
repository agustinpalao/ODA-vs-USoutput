# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ODA = pd.read_csv('ODA_OECD.csv')
China = pd.read_csv('China_projects.csv')

# %%
print('The size of the dataset: ' + str(China.shape))
China.head()
# Out:
# The size of the dataset: (6190, 34)
#    project_id project_location_id  precision_code  geoname_id   place_name  \
# 0          20          20_2475741               4     2475741   Tizi Ouzou
# 1          20          20_2502951               4     2502951       Bouira
# 2          20          20_2505325               4     2505325       Béjaïa
# 3         968         968_2572183               4     2572183  Brazzaville
# 4         981         981_2367237               4     2367237     Centrale
#
#    latitude  longitude location_type_code  \
# 0  36.75000    4.25000               ADM1
# 1  36.25000    3.91667               ADM1
# 2  36.66667    4.91667               ADM1
# 3  -4.26570   15.28048               ADM1
# 4   8.66667    1.00000               ADM1
#
#                     location_type_name     gazetteer_adm_code  ...  \
# 0  first-order administrative division  6295630|6255146|DZ|14  ...
# 1  first-order administrative division  6295630|6255146|DZ|21  ...
# ...

# %%
China.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6190 entries, 0 to 6189
# Data columns (total 34 columns):
# project_id                  6190 non-null int64
# project_location_id         6190 non-null object
# precision_code              6190 non-null int64
# geoname_id                  6190 non-null int64
# place_name                  6190 non-null object
# latitude                    4564 non-null float64
# longitude                   4564 non-null float64
# location_type_code          6190 non-null object
# location_type_name          6190 non-null object
# gazetteer_adm_code          6190 non-null object
# gazetteer_adm_name          6190 non-null object
# location_class              6190 non-null int64
# geographic_exactness        6190 non-null int64
# is_geocoded                 6190 non-null int64
# project_title               6190 non-null object
# start_actual_isodate        1447 non-null object
# start_actual_type           6190 non-null object
# ...

# %%
print('The size of the dataset: ' + str(ODA.shape))
ODA.head()
# Out:
# The size of the dataset: (1000000, 21)
#    RECIPIENT                    Recipient  DONOR                   Donor  \
# 0      10100  Developing Countries, Total  20005  Official Donors, Total
# 1      10100  Developing Countries, Total  20005  Official Donors, Total
# 2      10100  Developing Countries, Total  20005  Official Donors, Total
# 3      10100  Developing Countries, Total  20005  Official Donors, Total
# 4      10100  Developing Countries, Total  20005  Official Donors, Total
#
#    PART                               Part  AIDTYPE       Aid type DATATYPE  \
# 0     1  1 : Part I - Developing Countries      201  Grants, Total        A
# 1     1  1 : Part I - Developing Countries      201  Grants, Total        A
# 2     1  1 : Part I - Developing Countries      201  Grants, Total        A
# 3     1  1 : Part I - Developing Countries      201  Grants, Total        A
# 4     1  1 : Part I - Developing Countries      201  Grants, Total        A
#
# ...

# %%
ODA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 21 columns):
# RECIPIENT                1000000 non-null int64
# Recipient                1000000 non-null object
# DONOR                    1000000 non-null int64
# Donor                    1000000 non-null object
# PART                     1000000 non-null int64
# Part                     1000000 non-null object
# AIDTYPE                  1000000 non-null int64
# Aid type                 1000000 non-null object
# DATATYPE                 1000000 non-null object
# Amount type              1000000 non-null object
# TIME                     1000000 non-null int64
# Year                     1000000 non-null int64
# Unit Code                1000000 non-null object
# Unit                     1000000 non-null object
# PowerCode Code           1000000 non-null int64
# PowerCode                1000000 non-null object
# Reference Period Code    486235 non-null float64
# ...

# %%
ODA['Donor'].unique()
# Out:
# array(['Official Donors, Total', 'DAC Countries, Total', 'Australia',
#        'Austria', 'Belgium', 'Canada', 'Denmark', 'Finland', 'France',
#        'Germany', 'Greece', 'Ireland', 'Italy', 'Japan', 'Korea',
#        'Luxembourg', 'Netherlands', 'New Zealand', 'Norway', 'Portugal',
#        'Spain', 'Sweden', 'Switzerland', 'United Kingdom',
#        'United States', 'Multilaterals, Total',
#        'African Development Bank [AfDB]',
#        'African Development Fund [AfDF]', 'Arab Fund (AFESD)',
#        'Arab Bank for Economic Development in Africa [BADEA]',
#        'European Bank for Reconstruction and Development [EBRD]',
#        'EU Institutions',
#        'Global Alliance for Vaccines and Immunization [GAVI]',
#        'Global Environment Facility [GEF]', 'Global Fund',
#        'International Atomic Energy Agency [IAEA]',
#        'International Development Association [IDA]', 'IFAD',
#        'IMF (Concessional Trust Funds)',
# ...

# %%
ODA.loc[ODA['Donor']=='United States'].groupby('Year').mean()['Value']
#ODA.groupby('Year').mean(ODA[ODA['Donor']=='United States']['Value'])
# Out:
# Year
# 1989    207.658978
# 1990    267.633874
# 1991    292.786834
# 1992    246.032348
# 1993    205.068100
# 1994    210.269969
# 1995    151.208623
# 1996    191.696850
# 1997    139.999309
# 1998    130.577624
# 1999    156.792724
# 2000    159.546410
# 2001    170.083987
# 2002    218.965226
# 2003    309.893599
# 2004    334.922838
# 2005    479.359685
# 2006    390.555704
# 2007    325.460501
# 2008    401.777065
# 2009    441.407500
# 2010    440.723358
# 2011    491.599607
# 2012    453.843906
# 2013    465.783683
# 2014    472.797198
# 2015    460.991771
# 2016    485.740246
# 2017    517.944336
# Name: Value, dtype: float64

# %%
ODA.loc[ODA['Donor']=='United States']
# Out:
#         RECIPIENT                    Recipient  DONOR          Donor  PART  \
# 41118       10100  Developing Countries, Total    302  United States     1
# 41119       10100  Developing Countries, Total    302  United States     1
# 41120       10100  Developing Countries, Total    302  United States     1
# 41121       10100  Developing Countries, Total    302  United States     1
# 41122       10100  Developing Countries, Total    302  United States     1
# ...           ...                          ...    ...            ...   ...
# 997503        870                        Tonga    302  United States     1
# 997504        870                        Tonga    302  United States     1
# 997505        870                        Tonga    302  United States     1
# 997506        870                        Tonga    302  United States     1
# 997507        870                        Tonga    302  United States     1
#
#                                      Part  AIDTYPE  \
# ...

# %%
plt.plot(ODA.loc[ODA['Donor']=='United States'].groupby('Year').mean()['Value'])

# %%
plt.plot(China.groupby('transactions_start_year').mean()['total_commitments'])
